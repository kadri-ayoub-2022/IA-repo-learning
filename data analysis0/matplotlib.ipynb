# %% [markdown]
# ## Plots charts

# %%
import matplotlib.pyplot as plt
# see P2C4  for more information

# %% [markdown]
# ## Curve

# %%
import pandas as pd
revenue_change = pd.DataFrame({"date":['2013-01-01','2013-02-01','2013-03-01','2013-04-01'],"revenue":[180000,190000,170000,210000]})
plt.plot(revenue_change['date'], revenue_change["revenue"],
marker='o', linestyle='--', color='red')
